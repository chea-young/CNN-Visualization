# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import tensorflow as tf
from sklearn.metrics import f1_score 
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, MaxPooling2D, Dropout, Conv2D
# Loads the data required for detecting the license plates from cascade classifier.
plate_cascade = cv2.CascadeClassifier('./indian_license_plate.xml')
# add the path to 'india_license_plate.xml' file.
def detect_plate(img, text=''): # the function detects and perfors blurring on the number plate.
    plate_img = img.copy()
    roi = img.copy()
    plate_rect = plate_cascade.detectMultiScale(plate_img, scaleFactor = 1.2, minNeighbors = 7) # detects numberplates and returns the coordinates and dimensions of detected license plate's contours.
    for (x,y,w,h) in plate_rect:
        roi_ = roi[y:y+h, x:x+w, :] # extracting the Region of Interest of license plate for blurring.
        plate = roi[y:y+h, x:x+w, :]
        cv2.rectangle(plate_img, (x+2,y), (x+w-3, y+h-5), (51,181,155), 3) # finally representing the detected contours by drawing rectangles around the edges.
    if text!='':
        plate_img = cv2.putText(plate_img, text, (x-w//2,y-h//2), 
                                cv2.FONT_HERSHEY_COMPLEX_SMALL , 0.5, (51,181,155), 1, cv2.LINE_AA)
        
    return plate_img, plate # returning the processed image.
# Testing the above function
def display(img_, title=''):
    img = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
    fig = plt.figure(figsize=(10,6))
    ax = plt.subplot(111)
    ax.imshow(img)
    plt.axis('off')
    plt.title(title)
    plt.show()

img = cv2.imread('./car.jpg')
display(img, 'input image')

# %%
# Getting plate prom the processed image
output_img, plate = detect_plate(img)
display(output_img, 'detected license plate in the input image')

# %%
display(plate, 'extracted license plate from the image')

# %%
# Match contours to license plate or character template
def find_contours(dimensions, img) :

    # Find all contours in the image
    cntrs, _ = cv2.findContours(img.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # Retrieve potential dimensions
    lower_width = dimensions[0]
    upper_width = dimensions[1]
    lower_height = dimensions[2]
    upper_height = dimensions[3]
    
    # Check largest 5 or  15 contours for license plate or character respectively
    cntrs = sorted(cntrs, key=cv2.contourArea, reverse=True)[:15]
    
    ii = cv2.imread('contour.jpg')
    
    x_cntr_list = []
    target_contours = []
    img_res = []
    for cntr in cntrs :
        # detects contour in binary image and returns the coordinates of rectangle enclosing it
        intX, intY, intWidth, intHeight = cv2.boundingRect(cntr)
        
        # checking the dimensions of the contour to filter out the characters by contour's size
        if intWidth > lower_width and intWidth < upper_width and intHeight > lower_height and intHeight < upper_height :
            x_cntr_list.append(intX) #stores the x coordinate of the character's contour, to used later for indexing the contours

            char_copy = np.zeros((44,24))
            # extracting each character using the enclosing rectangle's coordinates.
            char = img[intY:intY+intHeight, intX:intX+intWidth]
            char = cv2.resize(char, (20, 40))
            
            cv2.rectangle(ii, (intX,intY), (intWidth+intX, intY+intHeight), (50,21,200), 2)
            plt.imshow(ii, cmap='gray')

            # Make result formatted for classification: invert colors
            char = cv2.subtract(255, char)

            # Resize the image to 24x44 with black border
            char_copy[2:42, 2:22] = char
            char_copy[0:2, :] = 0
            char_copy[:, 0:2] = 0
            char_copy[42:44, :] = 0
            char_copy[:, 22:24] = 0

            img_res.append(char_copy) # List that stores the character's binary image (unsorted)
            
    # Return characters on ascending order with respect to the x-coordinate (most-left character first)
            
    plt.show()
    # arbitrary function that stores sorted list of character indeces
    indices = sorted(range(len(x_cntr_list)), key=lambda k: x_cntr_list[k])
    img_res_copy = []
    for idx in indices:
        img_res_copy.append(img_res[idx])# stores character images according to their index
    img_res = np.array(img_res_copy)

    return img_res
  # Find characters in the resulting images
def segment_characters(image) :

    # Preprocess cropped license plate image
    img_lp = cv2.resize(image, (333, 75))
    img_gray_lp = cv2.cvtColor(img_lp, cv2.COLOR_BGR2GRAY)
    _, img_binary_lp = cv2.threshold(img_gray_lp, 200, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    img_binary_lp = cv2.erode(img_binary_lp, (3,3))
    img_binary_lp = cv2.dilate(img_binary_lp, (3,3))

    LP_WIDTH = img_binary_lp.shape[0]
    LP_HEIGHT = img_binary_lp.shape[1]

    # Make borders white
    img_binary_lp[0:3,:] = 255
    img_binary_lp[:,0:3] = 255
    img_binary_lp[72:75,:] = 255
    img_binary_lp[:,330:333] = 255

    # Estimations of character contours sizes of cropped license plates
    dimensions = [LP_WIDTH/6,
                       LP_WIDTH/2,
                       LP_HEIGHT/10,
                       2*LP_HEIGHT/3]
    plt.imshow(img_binary_lp, cmap='gray')
    plt.show()
    cv2.imwrite('contour.jpg',img_binary_lp)

    # Get contours within cropped license plate
    char_list = find_contours(dimensions, img_binary_lp)

    return char_list

  # Let's see the segmented characters
char = segment_characters(plate)

# %%
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(char[i], cmap='gray')
    plt.axis('off')

# %%
import tensorflow.keras.backend as K
train_datagen = ImageDataGenerator(rescale=1./255, width_shift_range=0.1, height_shift_range=0.1)
path = './data'
train_generator = train_datagen.flow_from_directory(
        path+'/train',  # this is the target directory
        target_size=(28,28),  # all images will be resized to 28x28
        batch_size=1,
        class_mode='sparse')

validation_generator = train_datagen.flow_from_directory(
        path+'/val',  # this is the target directory
        target_size=(28,28),  # all images will be resized to 28x28 batch_size=1,
        class_mode='sparse')
# Out:
# Found 931 images belonging to 5 classes.
# Found 216 images belonging to 36 classes.

# %%
# Metrics for checking the model performance while training
def f1score(y, y_pred):
  return f1_score(y, tf.math.argmax(y_pred, axis=1), average='micro') 

def custom_f1score(y, y_pred):
  return tf.py_function(f1score, (y, y_pred), tf.double)

# %%
K.clear_session()
model = Sequential()
model.add(Conv2D(16, (22,22), input_shape=(28, 28, 3), activation='relu', padding='same', name = 'conv2d_1'))
model.add(Conv2D(32, (16,16), input_shape=(28, 28, 3), activation='relu', padding='same', name = 'conv2d_2'))
model.add(Conv2D(64, (8,8), input_shape=(28, 28, 3), activation='relu', padding='same', name = 'conv2d_3'))
model.add(Conv2D(64, (4,4), input_shape=(28, 28, 3), activation='relu', padding='same', name = 'conv2d_4'))
model.add(MaxPooling2D(pool_size=(4, 4),name = 'maxpool_1'))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(36, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizers.Adam(lr=0.0001), metrics=[custom_f1score])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        23248
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 32)        131104
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 64)        131136
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 64)        65600
# _________________________________________________________________
# maxpool_1 (MaxPooling2D)     (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               401536
# _________________________________________________________________
# dense_1 (Dense)              (None, 36)                4644
# =================================================================
# Total params: 757,268
# Trainable params: 757,268
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
class stop_training_callback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_custom_f1score') > 0.99):
      self.model.stop_training = True

batch_size = 1
callbacks = [stop_training_callback()]
model.fit_generator(
      train_generator,
      steps_per_epoch = train_generator.samples // batch_size,
      validation_data = validation_generator, 
      epochs = 80, verbose=1, callbacks=callbacks, )
# Out:
# Epoch 1/80
#  21/931 [..............................] - ETA: 4s - loss: 0.0525 - custom_f1score: 1.0000
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 931/931 [==============================] - 6s 6ms/step - loss: 0.1492 - custom_f1score: 0.9227 - val_loss: 496.4409 - val_custom_f1score: 0.0312
# Epoch 2/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1164 - custom_f1score: 0.9270 - val_loss: 480.7050 - val_custom_f1score: 0.0312
# Epoch 3/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1183 - custom_f1score: 0.9313 - val_loss: 306.9174 - val_custom_f1score: 0.0312
# Epoch 4/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1278 - custom_f1score: 0.9130 - val_loss: 398.7836 - val_custom_f1score: 0.0250
# Epoch 5/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1198 - custom_f1score: 0.9205 - val_loss: 417.4299 - val_custom_f1score: 0.0312
# Epoch 6/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1188 - custom_f1score: 0.9194 - val_loss: 419.6960 - val_custom_f1score: 0.0250
# Epoch 7/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1165 - custom_f1score: 0.9237 - val_loss: 537.2004 - val_custom_f1score: 0.0312
# Epoch 8/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1192 - custom_f1score: 0.9205 - val_loss: 535.5833 - val_custom_f1score: 0.0375
# Epoch 9/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1265 - custom_f1score: 0.9173 - val_loss: 534.0267 - val_custom_f1score: 0.0375
# Epoch 10/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1189 - custom_f1score: 0.9194 - val_loss: 506.6195 - val_custom_f1score: 0.0250
# Epoch 11/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1162 - custom_f1score: 0.9216 - val_loss: 515.0024 - val_custom_f1score: 0.0250
# Epoch 12/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1183 - custom_f1score: 0.9270 - val_loss: 542.9795 - val_custom_f1score: 0.0375
# Epoch 13/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1171 - custom_f1score: 0.9205 - val_loss: 605.6449 - val_custom_f1score: 0.0250
# Epoch 14/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1870 - custom_f1score: 0.9280 - val_loss: 310.8500 - val_custom_f1score: 0.0250
# Epoch 15/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1117 - custom_f1score: 0.9291 - val_loss: 470.4850 - val_custom_f1score: 0.0312
# Epoch 16/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1151 - custom_f1score: 0.9227 - val_loss: 641.7147 - val_custom_f1score: 0.0250
# Epoch 17/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1163 - custom_f1score: 0.9248 - val_loss: 595.3934 - val_custom_f1score: 0.0312
# Epoch 18/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1176 - custom_f1score: 0.9194 - val_loss: 627.9178 - val_custom_f1score: 0.0250
# Epoch 19/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1141 - custom_f1score: 0.9248 - val_loss: 531.5162 - val_custom_f1score: 0.0312
# Epoch 20/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1776 - custom_f1score: 0.9119 - val_loss: 397.6282 - val_custom_f1score: 0.0250
# Epoch 21/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1150 - custom_f1score: 0.9280 - val_loss: 387.9660 - val_custom_f1score: 0.0312
# Epoch 22/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1185 - custom_f1score: 0.9173 - val_loss: 515.2229 - val_custom_f1score: 0.0250
# Epoch 23/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1469 - custom_f1score: 0.9184 - val_loss: 540.1255 - val_custom_f1score: 0.0188
# Epoch 24/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1162 - custom_f1score: 0.9227 - val_loss: 641.4476 - val_custom_f1score: 0.0312
# Epoch 25/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1213 - custom_f1score: 0.9302 - val_loss: 523.7399 - val_custom_f1score: 0.0312
# Epoch 26/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1239 - custom_f1score: 0.9184 - val_loss: 642.2621 - val_custom_f1score: 0.0250
# Epoch 27/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1296 - custom_f1score: 0.9227 - val_loss: 863.2285 - val_custom_f1score: 0.0250
# Epoch 28/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1151 - custom_f1score: 0.9259 - val_loss: 1041.4281 - val_custom_f1score: 0.0375
# Epoch 29/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1170 - custom_f1score: 0.9280 - val_loss: 768.2213 - val_custom_f1score: 0.0375
# Epoch 30/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1222 - custom_f1score: 0.9194 - val_loss: 505.4478 - val_custom_f1score: 0.0312
# Epoch 31/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1246 - custom_f1score: 0.9313 - val_loss: 677.1220 - val_custom_f1score: 0.0188
# Epoch 32/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1998 - custom_f1score: 0.9248 - val_loss: 689.1907 - val_custom_f1score: 0.0188
# Epoch 33/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1906 - custom_f1score: 0.9173 - val_loss: 844.5138 - val_custom_f1score: 0.0188
# Epoch 34/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1209 - custom_f1score: 0.9237 - val_loss: 685.0303 - val_custom_f1score: 0.0188
# Epoch 35/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1278 - custom_f1score: 0.9108 - val_loss: 984.8096 - val_custom_f1score: 0.0250
# Epoch 36/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1156 - custom_f1score: 0.9216 - val_loss: 1205.0990 - val_custom_f1score: 0.0188
# Epoch 37/80
# 931/931 [==============================] - 6s 6ms/step - loss: 0.1237 - custom_f1score: 0.9216 - val_loss: 839.9282 - val_custom_f1score: 0.0250
# Epoch 38/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1209 - custom_f1score: 0.9173 - val_loss: 614.2846 - val_custom_f1score: 0.0312
# Epoch 39/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1165 - custom_f1score: 0.9194 - val_loss: 834.0618 - val_custom_f1score: 0.0375
# Epoch 40/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1314 - custom_f1score: 0.9141 - val_loss: 828.1979 - val_custom_f1score: 0.0312
# Epoch 41/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1329 - custom_f1score: 0.9055 - val_loss: 969.6632 - val_custom_f1score: 0.0250
# Epoch 42/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1246 - custom_f1score: 0.9227 - val_loss: 833.3485 - val_custom_f1score: 0.0312
# Epoch 43/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1185 - custom_f1score: 0.9205 - val_loss: 840.9051 - val_custom_f1score: 0.0375
# Epoch 44/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1141 - custom_f1score: 0.9270 - val_loss: 891.4430 - val_custom_f1score: 0.0312
# Epoch 45/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1129 - custom_f1score: 0.9291 - val_loss: 922.0179 - val_custom_f1score: 0.0312
# Epoch 46/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1287 - custom_f1score: 0.9173 - val_loss: 798.9713 - val_custom_f1score: 0.0375
# Epoch 47/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1168 - custom_f1score: 0.9259 - val_loss: 797.6007 - val_custom_f1score: 0.0312
# Epoch 48/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1248 - custom_f1score: 0.9280 - val_loss: 909.3727 - val_custom_f1score: 0.0250
# Epoch 49/80
# 931/931 [==============================] - 6s 6ms/step - loss: 0.1255 - custom_f1score: 0.9119 - val_loss: 980.7991 - val_custom_f1score: 0.0312
# Epoch 50/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1171 - custom_f1score: 0.9162 - val_loss: 1361.0140 - val_custom_f1score: 0.0188
# Epoch 51/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.2101 - custom_f1score: 0.9237 - val_loss: 579.0769 - val_custom_f1score: 0.0250
# Epoch 52/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1143 - custom_f1score: 0.9227 - val_loss: 645.6078 - val_custom_f1score: 0.0312
# Epoch 53/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1156 - custom_f1score: 0.9184 - val_loss: 622.9716 - val_custom_f1score: 0.0375
# Epoch 54/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1198 - custom_f1score: 0.9162 - val_loss: 686.8704 - val_custom_f1score: 0.0312
# Epoch 55/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1180 - custom_f1score: 0.9248 - val_loss: 844.9357 - val_custom_f1score: 0.0250
# Epoch 56/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1437 - custom_f1score: 0.9248 - val_loss: 529.0549 - val_custom_f1score: 0.0312
# Epoch 57/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1220 - custom_f1score: 0.9259 - val_loss: 943.9536 - val_custom_f1score: 0.0063
# Epoch 58/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1155 - custom_f1score: 0.9216 - val_loss: 958.1562 - val_custom_f1score: 0.0312
# Epoch 59/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1273 - custom_f1score: 0.9248 - val_loss: 346.9963 - val_custom_f1score: 0.0375
# Epoch 60/80
# 931/931 [==============================] - 6s 6ms/step - loss: 0.1204 - custom_f1score: 0.9108 - val_loss: 1167.1667 - val_custom_f1score: 0.0375
# Epoch 61/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1419 - custom_f1score: 0.9237 - val_loss: 899.3895 - val_custom_f1score: 0.0312
# Epoch 62/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1140 - custom_f1score: 0.9302 - val_loss: 829.0026 - val_custom_f1score: 0.0312
# Epoch 63/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1163 - custom_f1score: 0.9237 - val_loss: 1080.6987 - val_custom_f1score: 0.0125
# Epoch 64/80
# 931/931 [==============================] - 6s 6ms/step - loss: 0.1276 - custom_f1score: 0.9184 - val_loss: 594.0071 - val_custom_f1score: 0.0312
# Epoch 65/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1132 - custom_f1score: 0.9323 - val_loss: 1282.6023 - val_custom_f1score: 0.0375
# Epoch 66/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1361 - custom_f1score: 0.9119 - val_loss: 1220.2946 - val_custom_f1score: 0.0375
# Epoch 67/80
# 931/931 [==============================] - 6s 6ms/step - loss: 0.1222 - custom_f1score: 0.9248 - val_loss: 1181.9012 - val_custom_f1score: 0.0250
# Epoch 68/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1169 - custom_f1score: 0.9237 - val_loss: 1184.7561 - val_custom_f1score: 0.0375
# Epoch 69/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1564 - custom_f1score: 0.9205 - val_loss: 781.1104 - val_custom_f1score: 0.0250
# Epoch 70/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1182 - custom_f1score: 0.9270 - val_loss: 1205.9723 - val_custom_f1score: 0.0312
# Epoch 71/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1264 - custom_f1score: 0.9151 - val_loss: 1755.9095 - val_custom_f1score: 0.0375
# Epoch 72/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1463 - custom_f1score: 0.9151 - val_loss: 925.9779 - val_custom_f1score: 0.0375
# Epoch 73/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1212 - custom_f1score: 0.9227 - val_loss: 927.4979 - val_custom_f1score: 0.0312
# Epoch 74/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1262 - custom_f1score: 0.9216 - val_loss: 798.6710 - val_custom_f1score: 0.0312
# Epoch 75/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1237 - custom_f1score: 0.9237 - val_loss: 1223.0341 - val_custom_f1score: 0.0188
# Epoch 76/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1160 - custom_f1score: 0.9205 - val_loss: 1455.8391 - val_custom_f1score: 0.0250
# Epoch 77/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1169 - custom_f1score: 0.9248 - val_loss: 1180.8320 - val_custom_f1score: 0.0375
# Epoch 78/80
# 931/931 [==============================] - 6s 6ms/step - loss: 0.1158 - custom_f1score: 0.9280 - val_loss: 1781.0865 - val_custom_f1score: 0.0312
# Epoch 79/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1194 - custom_f1score: 0.9216 - val_loss: 1523.5338 - val_custom_f1score: 0.0250
# Epoch 80/80
# 931/931 [==============================] - 5s 6ms/step - loss: 0.1493 - custom_f1score: 0.9162 - val_loss: 938.2360 - val_custom_f1score: 0.0312

# %%
# Predicting the output
def fix_dimension(img): 
  new_img = np.zeros((28,28,3))
  for i in range(3):
    new_img[:,:,i] = img
  return new_img
  
def show_results():
    dic = {}
    characters = '0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i,c in enumerate(characters):
        dic[i] = c

    output = []
    for i,ch in enumerate(char): #iterating over the characters
        img_ = cv2.resize(ch, (28,28), interpolation=cv2.INTER_AREA)
        img = fix_dimension(img_)
        img = img.reshape(1,28,28,3) #preparing image for the model
        y_ = model.predict_classes(img)[0] #predicting the class
        character = dic[y_] #
        output.append(character) #storing the result in a list
        
    plate_number = ''.join(output)
    
    return plate_number

print(show_results())

# Segmented characters and their predicted value.
plt.figure(figsize=(10,6))
for i,ch in enumerate(char):
    img = cv2.resize(ch, (28,28), interpolation=cv2.INTER_AREA)
    plt.subplot(3,4,i+1)
    plt.imshow(img,cmap='gray')
    plt.title(f'predicted: {show_results()[i]}')
    plt.axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 343XXXXIXI

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
def load_image(filename):
	# load the image
	img = load_img(filename, target_size=(28, 28))
	# convert to array
	img = img_to_array(img)
	# reshape into a single sample with 3 channels
	img = img.reshape(1, 28, 28, 3)
	# center pixel data
	img = img.astype('float32')
	#img = img - [123.68, 116.779, 103.939]
	return img

# %%
car_img = load_image('./car.jpg')

# %%
# modif -> lchy
import keras
layer_cnt = 5
layer_names = [layer.name for layer in model.layers[:layer_cnt]]
layer_outputs = [layer.output for layer in model.layers[:layer_cnt]]
activation_model = keras.models.Model(inputs=model.input,outputs=layer_outputs)
img_tensor = car_img
activations = activation_model.predict(img_tensor)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f05180ecdd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
  # This is the number of features in the feature map
  n_features = layer_activation.shape[-1]
  # The feature map has shape (1, size, size, n_features)
  size = layer_activation.shape[1]
  # We will tile the activation channels in this matrix
  n_cols = n_features // images_per_row
  # ksaehwa 실제 의미로 n_cols와 n_rows가 반대임 (변수명을 잘 못 지은 듯..)
  display_grid = np.zeros((size * n_cols, images_per_row * size))
  # We'll tile each filter into this big horizontal grid
  for col in range(n_cols): # ksaehwa col은 사실 row임
    for row in range(images_per_row): # ksaehwa row는 사실 col임
      channel_image = layer_activation[0, :, :, col * images_per_row + row]
      # Post-process the feature to make it visually palatable
      channel_image -= channel_image.mean()
      channel_image /= channel_image.std()
      channel_image *= 64
      channel_image += 128
      channel_image = np.clip(channel_image, 0, 255).astype('uint8')
      display_grid[col * size : (col + 1) * size,row * size : (row + 1) * size] = channel_image
  # Display the grid
  scale = 1. / size
  plt.figure(figsize=(scale * display_grid.shape[1], scale * display_grid.shape[0]))
  plt.title(layer_name + " #features=" + str(n_features) + " #rows=" +str(n_cols))
  plt.grid(False)
  plt.imshow(display_grid, aspect='auto', cmap = 'binary')
  plt.show()
